# %% [markdown]
# ## EDA in Military Expenditure

# %%
import pandas as pd

# %%
import random

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('military expenditure.csv')

# %%
df
# Out:
#            country iso3c iso2c  year  Military expenditure (current USD)  \
# 0      Afghanistan   AFG    AF  1970                        2.939586e+06
# 1      Afghanistan   AFG    AF  1971                                 NaN
# 2      Afghanistan   AFG    AF  1972                                 NaN
# 3      Afghanistan   AFG    AF  1973                        3.341272e+06
# 4      Afghanistan   AFG    AF  1974                        3.581366e+06
# ...            ...   ...   ...   ...                                 ...
# 13561     Zimbabwe   ZWE    ZW  2016                        3.580650e+08
# 13562     Zimbabwe   ZWE    ZW  2017                        3.405220e+08
# 13563     Zimbabwe   ZWE    ZW  2018                        4.203640e+08
# 13564     Zimbabwe   ZWE    ZW  2019                        5.469390e+08
# 13565     Zimbabwe   ZWE    ZW  2020                                 NaN
#
#        Military expenditure (% of general government expenditure)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13561                                           7.363048
# 13562                                           5.519890
# 13563                                           5.607096
# 13564                                           2.099816
# 13565                                                NaN
#
#        Military expenditure (% of GDP)  \
# 0                             1.629606
# 1                                  NaN
# 2                                  NaN
# 3                             1.868910
# 4                             1.610825
# ...                                ...
# 13561                         1.742494
# 13562                         1.544948
# 13563                         1.222795
# 13564                         0.698601
# 13565                              NaN
#
#                                       adminregion          incomeLevel
# 0                                      South Asia           Low income
# 1                                      South Asia           Low income
# 2                                      South Asia           Low income
# 3                                      South Asia           Low income
# 4                                      South Asia           Low income
# ...                                           ...                  ...
# 13561  Sub-Saharan Africa (excluding high income)  Lower middle income
# 13562  Sub-Saharan Africa (excluding high income)  Lower middle income
# 13563  Sub-Saharan Africa (excluding high income)  Lower middle income
# 13564  Sub-Saharan Africa (excluding high income)  Lower middle income
# 13565  Sub-Saharan Africa (excluding high income)  Lower middle income
#
# [13566 rows x 9 columns]

# %%
df.describe() #statistical characteristics
# Out:
#                year  Military expenditure (current USD)  \
# count  13566.000000                        8.769000e+03
# mean    1995.000000                        3.676065e+10
# std       14.720144                        1.422587e+11
# min     1970.000000                        0.000000e+00
# 25%     1982.000000                        1.200000e+08
# 50%     1995.000000                        1.148446e+09
# 75%     2008.000000                        8.533090e+09
# max     2020.000000                        1.928852e+12
#
#        Military expenditure (% of general government expenditure)  \
# count                                        5282.000000
# mean                                            7.658514
# std                                             6.048938
# min                                             0.000000
# 25%                                             3.665614
# 50%                                             6.033675
# 75%                                             9.996249
# max                                            57.478098
#
#        Military expenditure (% of GDP)
# count                      8777.000000
# mean                          2.722603
# std                           2.921869
# min                           0.000000
# 25%                           1.327207
# 50%                           2.013005
# 75%                           3.218261
# max                         117.349823

# %%
print(f'Dataset size: {df.shape}')
# Out:
# Dataset size: (13566, 9)

# %%
print(f'Columns:\n {list(df.columns)}')
# Out:
# Columns:
#  ['country', 'iso3c', 'iso2c', 'year', 'Military expenditure (current USD)', 'Military expenditure (% of general government expenditure)', 'Military expenditure (% of GDP)', 'adminregion', 'incomeLevel']

# %%
print(f'Data types : {df.dtypes}')
# Out:
# Data types : country                                                        object
# iso3c                                                          object
# iso2c                                                          object
# year                                                            int64
# Military expenditure (current USD)                            float64
# Military expenditure (% of general government expenditure)    float64
# Military expenditure (% of GDP)                               float64
# adminregion                                                    object
# incomeLevel                                                    object
# dtype: object

# %%
print(f'Number of missing values:\n{df.isna().sum()}')
# Out:
# Number of missing values:
# country                                                          0
# iso3c                                                          102
# iso2c                                                          153
# year                                                             0
# Military expenditure (current USD)                            4797
# Military expenditure (% of general government expenditure)    8284
# Military expenditure (% of GDP)                               4789
# adminregion                                                   6579
# incomeLevel                                                    102
# dtype: int64

# %%
df.country.value_counts()
# Out:
# country
# Afghanistan      51
# Norway           51
# Mozambique       51
# Myanmar          51
# Namibia          51
#                  ..
# Guam             51
# Guatemala        51
# Guinea           51
# Guinea-Bissau    51
# Zimbabwe         51
# Name: count, Length: 266, dtype: int64

# %%
countries = df.country.unique().tolist()
print(f'All countries:\n{countries}')
# Out:
# All countries:
# ['Afghanistan', 'Africa Eastern and Southern', 'Africa Western and Central', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands', 'Central African Republic', 'Central Europe and the Baltics', 'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Early-demographic dividend', 'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD countries)', 'East Asia & Pacific (excluding high income)', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Euro area', 'Europe & Central Asia', 'Europe & Central Asia (IDA & IBRD countries)', 'Europe & Central Asia (excluding high income)', 'European Union', 'Faroe Islands', 'Fiji', 'Finland', 'Fragile and conflict affected situations', 'France', 'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heavily indebted poor countries (HIPC)', 'High income', 'Honduras', 'Hong Kong SAR, China', 'Hungary', 'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total', 'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Late-demographic dividend', 'Latin America & Caribbean', 'Latin America & Caribbean (excluding high income)', 'Latin America & the Caribbean (IDA & IBRD countries)', 'Latvia', 'Least developed countries: UN classification', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Low & middle income', 'Low income', 'Lower middle income', 'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.', 'Middle East & North Africa', 'Middle East & North Africa (IDA & IBRD countries)', 'Middle East & North Africa (excluding high income)', 'Middle income', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North America', 'North Macedonia', 'Northern Mariana Islands', 'Norway', 'Not classified', 'OECD members', 'Oman', 'Other small states', 'Pacific island small states', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Post-demographic dividend', 'Pre-demographic dividend', 'Puerto Rico', 'Qatar', 'Romania', 'Russian Federation', 'Rwanda', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia', 'Small states', 'Solomon Islands', 'Somalia', 'South Africa', 'South Asia', 'South Asia (IDA & IBRD)', 'South Sudan', 'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia', 'St. Martin (French part)', 'St. Vincent and the Grenadines', 'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)', 'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname', 'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'To ...

# %%
len(countries)
# Out:
# 266

# %%
con = list[df.country.unique()]

# %%
con
# Out:
# list[array(['Afghanistan', 'Africa Eastern and Southern',
#        'Africa Western and Central', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Antigua and Barbuda',
#        'Arab World', 'Argentina', 'Armenia', 'Aruba', 'Australia',
#        'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda',
#        'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana',
#        'Brazil', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia',
#        'Cameroon', 'Canada', 'Caribbean small states', 'Cayman Islands',
#        'Central African Republic', 'Central Europe and the Baltics',
#        'Chad', 'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'East Asia & Pacific (excluding high income)', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (IDA & IBRD countries)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Faroe Islands', 'Fiji', 'Finland',
#        'Fragile and conflict affected situations', 'France',
#        'French Polynesia', 'Gabon', 'Gambia, The', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guam',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Honduras', 'Hong Kong SAR, China', 'Hungary', 'IBRD only',
#        'IDA & IBRD total', 'IDA blend', 'IDA only', 'IDA total',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)', 'Latvia',
#        'Least developed countries: UN classification', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Luxembourg', 'Macao SAR, China', 'Madagascar', 'Malawi',
#        'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands',
#        'Mauritania', 'Mauritius', 'Mexico', 'Micronesia, Fed. Sts.',
#        'Middle East & North Africa',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro',
#        'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#        'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua',
#        'Niger', 'Nigeria', 'North America', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'Not classified',
#        'OECD members', 'Oman', 'Other small states',
#        'Pacific island small states', 'Pakistan', 'Palau', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Post-demographic dividend',
#        'Pre-demographic dividend', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Small states', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Asia', 'South Asia (IDA & IBRD)', 'South Sudan', 'Spain',
#        'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD countries)',
#        'Sub-Saharan Africa (excluding high income)', 'Sudan', 'Suriname',
#        'Sweden', 'Switzerland', 'Syrian Arab Republic', 'Tajikistan',
#        'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'World', 'Yemen, Rep.', 'Zambia', 'Zimbabwe'],
#       dtype=object)]

# %%
df.incomeLevel.value_counts()
# Out:
# incomeLevel
# High income            4029
# Upper middle income    2805
# Lower middle income    2805
# Aggregates             2397
# Low income             1377
# Not classified           51
# Name: count, dtype: int64

# %%
# We will remove the excess for convenience of analyis
rf = df.loc[df['incomeLevel'] != 'Aggregates' , :]

# %%
rf.head()
# Out:
#        country iso3c iso2c  year  Military expenditure (current USD)  \
# 0  Afghanistan   AFG    AF  1970                        2.939586e+06
# 1  Afghanistan   AFG    AF  1971                                 NaN
# 2  Afghanistan   AFG    AF  1972                                 NaN
# 3  Afghanistan   AFG    AF  1973                        3.341272e+06
# 4  Afghanistan   AFG    AF  1974                        3.581366e+06
#
#    Military expenditure (% of general government expenditure)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Military expenditure (% of GDP) adminregion incomeLevel
# 0                         1.629606  South Asia  Low income
# 1                              NaN  South Asia  Low income
# 2                              NaN  South Asia  Low income
# 3                         1.868910  South Asia  Low income
# 4                         1.610825  South Asia  Low income

# %%
rf.shape
# Out:
# (11169, 9)

# %%
rf.incomeLevel.value_counts()
# Out:
# incomeLevel
# High income            4029
# Upper middle income    2805
# Lower middle income    2805
# Low income             1377
# Not classified           51
# Name: count, dtype: int64

# %% [markdown]
# ## EDA

# %%
df['year'].min(),df['year'].max()
# Out:
# (1970, 2020)

# %%
plt.figure(figsize=(20,8))
years = [i for i in range(df['year'].min() , df['year'].max() +1)]

# %%
plt.grid()

# %%
world_military_expenditure = df[df['country'] == 'World']['Military expenditure (current USD)']

# %%
world_military_expenditure.index=years
sns.lineplot(world_military_expenditure)
plt.title('Military spending around the world for 1980-2020' , fontsize=18)
plt.xlabel('year' , fontsize=18)
plt.ylabel('spending' , fontsize=18)
plt.xticks(rotation=30 , fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %% [markdown]
# ## conclusion
# ## Between 1990 and 2000 changes are insignificantly
# ## between 2014 and 2020 , military spending around the wirld dod not change
# ## sharp increases is noted in the period from 2002 to 2012

# %%
rf.groupby('country').max()
# Out:
#                       iso3c iso2c  year  Military expenditure (current USD)  \
# country
# Afghanistan             AFG    AF  2020                        3.258070e+08
# Albania                 ALB    AL  2020                        2.556780e+08
# Algeria                 DZA    DZ  2020                        1.041271e+10
# American Samoa          ASM    AS  2020                                 NaN
# Andorra                 AND    AD  2020                                 NaN
# ...                     ...   ...   ...                                 ...
# Virgin Islands (U.S.)   VIR    VI  2020                                 NaN
# West Bank and Gaza      PSE    PS  2020                                 NaN
# Yemen, Rep.             YEM    YE  2020                        2.353269e+09
# Zambia                  ZMB    ZM  2020                        4.436047e+08
# Zimbabwe                ZWE    ZW  2020                        6.770000e+08
#
#                        Military expenditure (% of general government expenditure)  \
# country
# Afghanistan                                                    16.134336
# Albania                                                         6.256198
# Algeria                                                        16.989554
# American Samoa                                                       NaN
# Andorra                                                              NaN
# ...                                                                  ...
# Virgin Islands (U.S.)                                                NaN
# West Bank and Gaza                                                   NaN
# Yemen, Rep.                                                    33.352214
# Zambia                                                          8.294228
# Zimbabwe                                                       23.266187
#
#                        Military expenditure (% of GDP)  \
# country
# Afghanistan                                   2.566267
# Albania                                       6.117505
# Algeria                                       6.659994
# American Samoa                                     NaN
# Andorra                                            NaN
# ...                                                ...
# Virgin Islands (U.S.)                              NaN
# West Bank and Gaza                                 NaN
# Yemen, Rep.                                   8.398759
# Zambia                                        4.195269
# Zimbabwe                                      8.520521
#
#                                                              adminregion  \
# country
# Afghanistan                                                   South Asia
# Albania                    Europe & Central Asia (excluding high income)
# Algeria                Middle East & North Africa (excluding high inc...
# American Samoa               East Asia & Pacific (excluding high income)
# Andorra                                                              NaN
# ...                                                                  ...
# Virgin Islands (U.S.)                                                NaN
# West Bank and Gaza     Middle East & North Africa (excluding high inc...
# Yemen, Rep.            Middle East & North Africa (excluding high inc...
# Zambia                        Sub-Saharan Africa (excluding high income)
# Zimbabwe                      Sub-Saharan Africa (excluding high income)
#
#                                incomeLevel
# country
# Afghanistan                     Low income
# Albania                Upper middle income
# Algeria                Lower middle income
# American Samoa         Upper middle income
# Andorra                        High income
# ...                                    ...
# Virgin Islands (U.S.)          High income
# West Bank and Gaza     Lower middle income
# Yemen, Rep.                     Low income
# Zambia                 Lower middle income
# Zimbabwe               Lower middle income
#
# [219 rows x 8 columns]

# %%
max_min =rf.groupby('country').max()['Military expenditure (current USD)']

# %%
top_10 = max_min.nlargest(10)

# %%
top_10.index
# Out:
# Index(['United States', 'China', 'Russian Federation', 'Saudi Arabia',
#        'Latin America & Caribbean', 'United Kingdom', 'India', 'Japan',
#        'France', 'Germany'],
#       dtype='object', name='country')

# %%
plt.figure(figsize=(20, 8))
plt.title('Countries with the largest increase in military spending', fontsize=18)
plt.ylabel('Maximum spending - minimum spending', fontsize=18)
sns.barplot(top_10,palette='magma')
plt.xticks(rotation=30, fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Country', fontsize=18)
plt.show()

# %% [markdown]
# ## conclusin:
# ## For the period 1970-20202 , america's laregst increases in military spending

# %%
top_5 = rf.groupby('country').sum()['Military expenditure (current USD)'].nlargest(5)
top_5 = list(top_5.index)

# %%
top_5
# Out:
# ['United States', 'China', 'United Kingdom', 'France', 'Japan']

# %%
def plotter_1(top_5):
    plt.figure(figsize=(20, 8))
    plt.title('Military expenditure of 5 countries (max values) for different times', fontsize=18 )
    YEARS = [i for i in range(df['year'].min(), df['year'].max() + 1)]
    for top_country in top_5:
        country_data = df[df['country'] == top_country]
        sns.lineplot(x=country_data['year'], y=country_data['Military expenditure (current USD)'] , label=top_country)
    plt.legend(fontsize=18) 
    plt.xticks(rotation=30 , fontsize=18)
    plt.yticks(fontsize=18)
    plt.xlabel('year', fontsize=18)
    plt.ylabel('Military expenditure (current USD)' , fontsize=18)
    plt.grid()
plotter_1(top_5)
plt.show()

# %%
tf = df.loc[df['Military expenditure (current USD)'] >0, :]
#Find the 5 countries with the smallest tota; military expenditure

smallest_5 = tf.groupby('country').sum()['Military expenditure (current USD)'].nsmallest(5)
smallest_5 = list(smallest_5.index)
def plotter_10(smallest_5):
    plt.figure(figsize=(20, 8))
    plt.title('5 countries with the lowest military spending for the period 1970-2020', fontsize=18)
    YEARS = [i for i in range(df['year'].min() , df['year'].max() + 1)]
    for country in smallest_5:
        country_data = df[df['country'] == country]
        sns.lineplot(x=country_data['year'], y=country_data['Military expenditure (current USD)'], label=country)
    plt.legend(fontsize=18)
    plt.xticks(rotation=30, fontsize=18)
    plt.yticks(fontsize=18)
    plt.xlabel('year', fontsize=18)
    plt.ylabel('Military expenditure (current USD )' , fontsize=18)
    plt.grid()
plotter_10(smallest_5)
plt.show()

# %%
income_level_list = df['incomeLevel'].dropna().unique().tolist()
income_level_list.remove('Not classified')
income_level_list.remove('Aggregates')
income_level_list
# Out:
# ['Low income', 'Upper middle income', 'Lower middle income', 'High income']

# %%
mf = pd.DataFrame(df.groupby('incomeLevel').sum()['Military expenditure (current USD)'])
mf.drop(index=['Aggregates', 'Not classified'], inplace=True)
explode = (0.05 , 0.05 , 0.05, 0.05)
plt.figure(figsize=(10 , 10))
plt.title('''The ratio of the tota; Military spending of countries with different levels of income of the proulation for the period 1970-2020''', fontsize =17)
plt.pie(mf['Military expenditure (current USD)'], labels=income_level_list, autopct='%1.1f%%', shadow= False,
       wedgeprops={'lw':1, 'ls': '--', 'edgecolor': 'k'}, rotatelabels=True, explode=explode,colors=sns.color_palette('pastel')[0:4],textprops={'fontsize':14})
plt.show()

# %% [markdown]
# ## conclusion :
# ## The chart shows that low income countries have the highest total military spending

# %%
df_update = df[df['country'].isin(['Low income' , 'Lower middle income' , 'upper middle income' , 'High income'])]
df_update = df_update.loc[:, ['country' , 'year' , 'Military expenditure (% of general government expenditure)']]

# Function to plot military expenditure for a given income level
def plotter_3(income_level):
    income_data = df_update[df_update['country'] == income_level]
    sns.lineplot(x=income_data['year'], y=income_data['Military expenditure (% of general government expenditure)'],
                 label=f'{income_level} level')

# Set up the plot
plt.figure(figsize=(20, 10))
plt.title('Military expenditure (% of general government expenditure) for countries with different income levels', fontsize=17)
plt.xlabel('Year', fontsize=17)
plt.ylabel('Military expenditure (% of general government expenditure)', fontsize=17)
plt.grid()

# Plot for each income level
plotter_3('High income')
plotter_3('Upper middle income')
plotter_3('Lower middle income')
plotter_3('Low income')

# Customize the ticks and legend
plt.xticks(fontsize=17)
plt.yticks(fontsize=17)
plt.legend(fontsize=17)

# Show the plot
plt.show()

# %% [markdown]
# ## conclusion :
# ## And low income level countires lead the way , although military expenditure (% of general government expenditure ) has declined over the past 15 years
